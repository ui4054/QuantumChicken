# %% [markdown]
# # 🚀 Guía de Configuración: Python con Anaconda, VS Code e Importación de Entorno
#
# Esta guía te ayudará a configurar tu entorno de trabajo en **Windows** usando **Anaconda** y **Visual Studio Code (VS Code)**.
#
# ---
#
# ## 1️⃣ Crear carpeta de trabajo
#
# 1. Abre el explorador de archivos.
# 2. Crea una carpeta en tu disco duro, por ejemplo:
#
# >**"c:/quantumhub/"**
#
# 3. Copia dentro de esta carpeta el archivo `entorno.yml` que te entregó el profesor.
#    👉 Aquí también guardarás tus notebooks y proyectos.
#
# ---

# %% [markdown]
# ## 2️⃣ Instalar Anaconda
#
# 1. Descarga **Anaconda Individual Edition** desde:
#    👉 [https://www.anaconda.com/download](https://www.anaconda.com/download)
# 2. Durante la instalación:
#    - Selecciona *“Add Anaconda to PATH”* (si aparece).
#    - Mantén *“Register Anaconda as default Python”* activado.
#
# ---

# %% [markdown]
# ## 3️⃣ Importar un entorno desde archivo `.yml`
#
# 1. Abre **Anaconda Prompt**.
# 2. Cambia al directorio donde guardaste el archivo:
#
# > cd RUTA_A_TU_CARPETA
#
# 3. Crea el entorno desde el archivo `entorno.yml`:
#
# > conda env create -f entorno.yml
#
# 4. Activa el entorno (quantumhub):
#
# > conda activate quantumhub
#
# *(El nombre está en la primera línea del `.yml`, después de `name:`)*
#
# ---

# %% [markdown]
# ## 4️⃣ Instalar Visual Studio Code
#
# 1. Descarga VS Code desde:
#    👉 [https://code.visualstudio.com/](https://code.visualstudio.com/)
# 2. Instálalo con las opciones por defecto.
# 3. Abre VS Code.
#
# ---

# %% [markdown]
# ## 5️⃣ Instalar extensiones recomendadas en VS Code
#
# En la barra lateral izquierda (icono de cuadrados), instala:
#
# - **Python** (Microsoft, imprescindible)
# - **Jupyter** (para notebooks dentro de VS Code)
# - **Pylance** (intellisense avanzado de Python)
# - **Jupyter Keymap** y **Jupyter Notebook Renderers**
# - *(Opcional)* **GitHub Copilot** o **Code Spell Checker**
#
# ---

# %% [markdown]
# ## 6️⃣ Conectar VS Code con el entorno importado
#
# 1. Abre la **paleta de comandos** en VS Code (Ctrl+Shift+P o ⇧⌘P en Mac).
# 2. Busca **“Python: Select Interpreter”**.
# 3. Selecciona el entorno que importaste (aparecerá como `Python (nombre_del_entorno)`).
#    👉 Si no aparece, reinicia VS Code.
#
# ---

# %% [markdown]
# ## 7️⃣ Probar con un Notebook
#
# 1. En VS Code, abre la carpeta donde guardaste el entorno (`RUTA_A_TU_CARPETA`).
# 2. Crea un archivo `prueba.ipynb`.
# 3. Selecciona el kernel del entorno importado.
# 4. Escribe y ejecuta:

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\messe\anaconda3\envs\nickel20\python.exe
